# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
star_wars=pd.read_csv('starwars.csv')

# %%
star_wars
# Out:
#               name  height   mass hair_color   skin_color eye_color  \
# 0   Luke Skywalker   172.0   77.0      blond         fair      blue
# 1            C-3PO   167.0   75.0        NaN         gold    yellow
# 2            R2-D2    96.0   32.0        NaN  white, blue       red
# 3      Darth Vader   202.0  136.0       none        white    yellow
# 4      Leia Organa   150.0   49.0      brown        light     brown
# ..             ...     ...    ...        ...          ...       ...
# 82             Rey     NaN    NaN      brown        light     hazel
# 83     Poe Dameron     NaN    NaN      brown        light     brown
# 84             BB8     NaN    NaN       none         none     black
# 85  Captain Phasma     NaN    NaN    unknown      unknown   unknown
# 86   Padmé Amidala   165.0   45.0      brown        light     brown
#
#     birth_year     sex     gender homeworld species  \
# 0         19.0    male  masculine  Tatooine   Human
# ...

# %%
star_wars.size
# Out:
# 1218

# %%
star_wars.shape
# Out:
# (87, 14)

# %%
star_wars.shape[0]
star_wars.shape[1]
# Out:
# 14

# %%
print(star_wars.shape[0])
print(star_wars.shape[1])
# Out:
# 87
# 14

# %%
star_wars.head()
# Out:
#              name  height   mass hair_color   skin_color eye_color  \
# 0  Luke Skywalker   172.0   77.0      blond         fair      blue
# 1           C-3PO   167.0   75.0        NaN         gold    yellow
# 2           R2-D2    96.0   32.0        NaN  white, blue       red
# 3     Darth Vader   202.0  136.0       none        white    yellow
# 4     Leia Organa   150.0   49.0      brown        light     brown
#
#    birth_year     sex     gender homeworld species  \
# 0        19.0    male  masculine  Tatooine   Human
# 1       112.0    none  masculine  Tatooine   Droid
# 2        33.0    none  masculine     Naboo   Droid
# 3        41.9    male  masculine  Tatooine   Human
# 4        19.0  female   feminine  Alderaan   Human
#
#                                                films  \
# 0  The Empire Strikes Back, Revenge of the Sith, ...
# 1  The Empire Strikes Back, Attack of the Clones,...
# 2  The Empire Strikes Back, Attack of the Clones,...
# ...

# %%
star_wars.tail()
# Out:
#               name  height  mass hair_color skin_color eye_color  birth_year  \
# 82             Rey     NaN   NaN      brown      light     hazel         NaN
# 83     Poe Dameron     NaN   NaN      brown      light     brown         NaN
# 84             BB8     NaN   NaN       none       none     black         NaN
# 85  Captain Phasma     NaN   NaN    unknown    unknown   unknown         NaN
# 86   Padmé Amidala   165.0  45.0      brown      light     brown        46.0
#
#        sex     gender homeworld species  \
# 82  female   feminine       NaN   Human
# 83    male  masculine       NaN   Human
# 84    none  masculine       NaN   Droid
# 85     NaN        NaN       NaN     NaN
# 86  female   feminine     Naboo   Human
#
#                                                 films vehicles  \
# 82                                  The Force Awakens      NaN
# 83                                  The Force Awakens      NaN
# 84                                  The Force Awakens      NaN
# ...

# %%
star_wars.head(n=10)
# Out:
#                  name  height   mass     hair_color   skin_color  eye_color  \
# 0      Luke Skywalker   172.0   77.0          blond         fair       blue
# 1               C-3PO   167.0   75.0            NaN         gold     yellow
# 2               R2-D2    96.0   32.0            NaN  white, blue        red
# 3         Darth Vader   202.0  136.0           none        white     yellow
# 4         Leia Organa   150.0   49.0          brown        light      brown
# 5           Owen Lars   178.0  120.0    brown, grey        light       blue
# 6  Beru Whitesun lars   165.0   75.0          brown        light       blue
# 7               R5-D4    97.0   32.0            NaN   white, red        red
# 8   Biggs Darklighter   183.0   84.0          black        light      brown
# 9      Obi-Wan Kenobi   182.0   77.0  auburn, white         fair  blue-gray
#
#    birth_year     sex     gender homeworld species  \
# 0        19.0    male  masculine  Tatooine   Human
# ...

# %%
star_wars.tail(n=10)
# Out:
#                name  height   mass hair_color skin_color eye_color  \
# 77          Tarfful   234.0  136.0      brown      brown      blue
# 78  Raymus Antilles   188.0   79.0      brown      light     brown
# 79        Sly Moore   178.0   48.0       none       pale     white
# 80       Tion Medon   206.0   80.0       none       grey     black
# 81             Finn     NaN    NaN      black       dark      dark
# 82              Rey     NaN    NaN      brown      light     hazel
# 83      Poe Dameron     NaN    NaN      brown      light     brown
# 84              BB8     NaN    NaN       none       none     black
# 85   Captain Phasma     NaN    NaN    unknown    unknown   unknown
# 86    Padmé Amidala   165.0   45.0      brown      light     brown
#
#     birth_year     sex     gender homeworld  species  \
# 77         NaN    male  masculine  Kashyyyk  Wookiee
# 78         NaN    male  masculine  Alderaan    Human
# 79         NaN     NaN        NaN    Umbara      NaN
# ...

# %%
star_wars2=pd.read_csv('starwars.csv', index_col='height')
star_wars2
# Out:
#                   name   mass hair_color   skin_color eye_color  birth_year  \
# height
# 172.0   Luke Skywalker   77.0      blond         fair      blue        19.0
# 167.0            C-3PO   75.0        NaN         gold    yellow       112.0
# 96.0             R2-D2   32.0        NaN  white, blue       red        33.0
# 202.0      Darth Vader  136.0       none        white    yellow        41.9
# 150.0      Leia Organa   49.0      brown        light     brown        19.0
# ...                ...    ...        ...          ...       ...         ...
# NaN                Rey    NaN      brown        light     hazel         NaN
# NaN        Poe Dameron    NaN      brown        light     brown         NaN
# NaN                BB8    NaN       none         none     black         NaN
# NaN     Captain Phasma    NaN    unknown      unknown   unknown         NaN
# 165.0    Padmé Amidala   45.0      brown        light     brown        46.0
#
#            sex     gender homeworld species  \
# ...

# %%
star_wars.drop(columns=['mass'])
# Out:
#               name  height hair_color   skin_color eye_color  birth_year  \
# 0   Luke Skywalker   172.0      blond         fair      blue        19.0
# 1            C-3PO   167.0        NaN         gold    yellow       112.0
# 2            R2-D2    96.0        NaN  white, blue       red        33.0
# 3      Darth Vader   202.0       none        white    yellow        41.9
# 4      Leia Organa   150.0      brown        light     brown        19.0
# ..             ...     ...        ...          ...       ...         ...
# 82             Rey     NaN      brown        light     hazel         NaN
# 83     Poe Dameron     NaN      brown        light     brown         NaN
# 84             BB8     NaN       none         none     black         NaN
# 85  Captain Phasma     NaN    unknown      unknown   unknown         NaN
# 86   Padmé Amidala   165.0      brown        light     brown        46.0
#
#        sex     gender homeworld species  \
# 0     male  masculine  Tatooine   Human
# ...

# %%
star_wars3=pd.read_csv('starwars.csv', usecols=['name', 'height', 'hair_color', 'skin_color'])
star_wars3
# Out:
#               name  height hair_color   skin_color
# 0   Luke Skywalker   172.0      blond         fair
# 1            C-3PO   167.0        NaN         gold
# 2            R2-D2    96.0        NaN  white, blue
# 3      Darth Vader   202.0       none        white
# 4      Leia Organa   150.0      brown        light
# ..             ...     ...        ...          ...
# 82             Rey     NaN      brown        light
# 83     Poe Dameron     NaN      brown        light
# 84             BB8     NaN       none         none
# 85  Captain Phasma     NaN    unknown      unknown
# 86   Padmé Amidala   165.0      brown        light
#
# [87 rows x 4 columns]

# %%
star_wars['name']
# Out:
# 0     Luke Skywalker
# 1              C-3PO
# 2              R2-D2
# 3        Darth Vader
# 4        Leia Organa
#            ...
# 82               Rey
# 83       Poe Dameron
# 84               BB8
# 85    Captain Phasma
# 86     Padmé Amidala
# Name: name, Length: 87, dtype: object

# %%
star_wars.dtypes
# Out:
# name           object
# height        float64
# mass          float64
# hair_color     object
# skin_color     object
# eye_color      object
# birth_year    float64
# sex            object
# gender         object
# homeworld      object
# species        object
# films          object
# vehicles       object
# starships      object
# dtype: object

# %%
eye_color=star_wars['eye_color']

# %%
eye_color
# Out:
# 0        blue
# 1      yellow
# 2         red
# 3      yellow
# 4       brown
#        ...
# 82      hazel
# 83      brown
# 84      black
# 85    unknown
# 86      brown
# Name: eye_color, Length: 87, dtype: object

# %%
eyes=eye_color.value_counts()

# %%
eyes.plot(kind='bar')

# %%
#Some things to learn:
#How to find and replace data, if possible? 
#Delete missing values in data 
#Clean up data better, more in-depth analysis
#See how pandas, matplotlib, and numpy all relate? 
#Figure out whatever numpy does LOL

# %%
eyes.plot(kind='barh')

# %%
eyes.plot(kind='hist')
