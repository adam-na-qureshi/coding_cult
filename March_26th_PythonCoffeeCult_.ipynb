# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %% [markdown]
# csv = comma separated variables -- delimited by a coma (sep=',')
#
# tsv = tab separated variables -- delimited by a space, tab, or white space (sep=" ", sep '\t')
#
# delimited file

# %%
movies=pd.read_csv('IMDB.csv')

# %%
movies
# Out:
#        X                              Title  Rating  TotalVotes     Genre1  \
# 0      1            12 Years a Slave (2013)     8.1      496092  Biography
# 1      2                   127 Hours (2010)     7.6      297075  Adventure
# 2      3                       50/50 (2011)     7.7      283935     Comedy
# 3      4                  About Time (2013)     7.8      225412     Comedy
# 4      5                       Amour (2012)     7.9       76121      Drama
# ..   ...                                ...     ...         ...        ...
# 112  114                    Whiplash (2014)     8.5      492285      Drama
# 113  115              Wreck-It Ralph (2012)     7.7      295125  Animation
# 114  116  X-Men: Days of Future Past (2014)     8.0      560736     Action
# 115  117          X-Men: First Class (2011)     7.8      556713     Action
# 116  118                    Zootopia (2016)     8.1      309474  Animation
#
# ...

# %%
#Dimensions of the data set tell you how many rows and how many columns
#r x c 

movies.shape 
print(movies.shape) #Will print both rows and columns in r x c format
print(movies.shape[0]) #Will print only # of rows
print(movies.shape[1]) #Will print only # of columns
# Out:
# (117, 58)
# 117
# 58

# %%
#Drop a column

movies=movies.drop(columns=["X"])

#movies=movies.drop(['X'], axis=1) #Same as above, but axis 1 is columns since r x c rows is 0
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-7-67acf53c82fa> in <module>
#       1 #Drop a column
#       2
# ----> 3 movies=movies.drop(columns=["X"])
#       4
#       5 #movies=movies.drop(['X'], axis=1) #Same as above, but axis 1 is columns since r x c rows is 0
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4100             level=level,
#    4101             inplace=inplace,
# -> 4102             errors=errors,
#    4103         )
#    4104
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3912         for axis, labels in axes.items():
#    3913             if labels is not None:
# -> 3914                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3915
# ...

# %%
movies.head()
# Out:
#                      Title  Rating  TotalVotes     Genre1     Genre2   Genre3  \
# 0  12 Years a Slave (2013)     8.1      496092  Biography      Drama  History
# 1         127 Hours (2010)     7.6      297075  Adventure  Biography    Drama
# 2             50/50 (2011)     7.7      283935     Comedy      Drama  Romance
# 3        About Time (2013)     7.8      225412     Comedy      Drama  Fantasy
# 4             Amour (2012)     7.9       76121      Drama    Romance      NaN
#
#    MetaCritic      Budget  Runtime  CVotes10  ...  Votes45A  Votes45AM  \
# 0        96.0  20000000.0  134 min     75556  ...       7.8        7.8
# 1        82.0  18000000.0   94 min     28939  ...       7.3        7.3
# 2        72.0   8000000.0  100 min     28304  ...       7.4        7.4
# 3         NaN  12000000.0  123 min     38556  ...       7.6        7.5
# 4        94.0   8900000.0  127 min     11093  ...       7.9        7.8
#
# ...

# %%
movies.head(n=10)
# Out:
#                                                Title  Rating  TotalVotes  \
# 0                            12 Years a Slave (2013)     8.1      496092
# 1                                   127 Hours (2010)     7.6      297075
# 2                                       50/50 (2011)     7.7      283935
# 3                                  About Time (2013)     7.8      225412
# 4                                       Amour (2012)     7.9       76121
# 5                                        Argo (2012)     7.7      486840
# 6                                     Arrival (2016)     8.0      370842
# 7                             Before Midnight (2013)     7.9      106553
# 8                                  Big Hero 6 (2014)     7.8      315485
# 9  Birdman or (The Unexpected Virtue of Ignorance...     7.8      448725
#
#       Genre1     Genre2     Genre3  MetaCritic       Budget  Runtime  \
# 0  Biography      Drama    History        96.0   20000000.0  134 min
# ...

# %%
movies.tail()
# Out:
#                                  Title  Rating  TotalVotes     Genre1  \
# 112                    Whiplash (2014)     8.5      492285      Drama
# 113              Wreck-It Ralph (2012)     7.7      295125  Animation
# 114  X-Men: Days of Future Past (2014)     8.0      560736     Action
# 115          X-Men: First Class (2011)     7.8      556713     Action
# 116                    Zootopia (2016)     8.1      309474  Animation
#
#         Genre2  Genre3  MetaCritic       Budget  Runtime  CVotes10  ...  \
# 112      Music     NaN        88.0    3300000.0  107 min    110404  ...
# 113  Adventure  Comedy        72.0  165000000.0      NaN     41980  ...
# 114  Adventure  Sci-Fi        74.0  200000000.0  132 min     91765  ...
# 115  Adventure  Sci-Fi        65.0  160000000.0  132 min     64428  ...
# 116  Adventure  Comedy        78.0  150000000.0  108 min     53626  ...
#
#      Votes45A  Votes45AM  Votes45AF  VotesIMDB  Votes1000  VotesUS  VotesnUS  \
# ...

# %%
movies.tail(n=2)
# Out:
#                          Title  Rating  TotalVotes     Genre1     Genre2  \
# 115  X-Men: First Class (2011)     7.8      556713     Action  Adventure
# 116            Zootopia (2016)     8.1      309474  Animation  Adventure
#
#      Genre3  MetaCritic       Budget  Runtime  CVotes10  ...  Votes45A  \
# 115  Sci-Fi        65.0  160000000.0  132 min     64428  ...       7.6
# 116  Comedy        78.0  150000000.0  108 min     53626  ...       7.8
#
#      Votes45AM  Votes45AF  VotesIMDB  Votes1000  VotesUS  VotesnUS  \
# 115        7.5        7.7        7.6        7.3      7.8       7.7
# 116        7.8        8.1        7.7        7.6      8.0       8.0
#
#           Domestic    Foreign        Worldwide
# 115  $146,408,305   207215819    $353,624,124
# 116  $341,268,248   682515947  $1,023,784,195
#
# [2 rows x 57 columns]

# %%
# Specify a column as an index when we load the file, instead of the default row numbers

movies2=pd.read_csv('IMDB.csv', index_col="Title")
movies2.head()
# Out:
#                          X  Rating  TotalVotes     Genre1     Genre2   Genre3  \
# Title
# 12 Years a Slave (2013)  1     8.1      496092  Biography      Drama  History
# 127 Hours (2010)         2     7.6      297075  Adventure  Biography    Drama
# 50/50 (2011)             3     7.7      283935     Comedy      Drama  Romance
# About Time (2013)        4     7.8      225412     Comedy      Drama  Fantasy
# Amour (2012)             5     7.9       76121      Drama    Romance      NaN
#
#                          MetaCritic      Budget  Runtime  CVotes10  ...  \
# Title                                                               ...
# 12 Years a Slave (2013)        96.0  20000000.0  134 min     75556  ...
# 127 Hours (2010)               82.0  18000000.0   94 min     28939  ...
# 50/50 (2011)                   72.0   8000000.0  100 min     28304  ...
# About Time (2013)               NaN  12000000.0  123 min     38556  ...
# ...

# %%
movies2=movies2.drop(columns=["X"])
movies2.head()
# Out:
#                          Rating  TotalVotes     Genre1     Genre2   Genre3  \
# Title
# 12 Years a Slave (2013)     8.1      496092  Biography      Drama  History
# 127 Hours (2010)            7.6      297075  Adventure  Biography    Drama
# 50/50 (2011)                7.7      283935     Comedy      Drama  Romance
# About Time (2013)           7.8      225412     Comedy      Drama  Fantasy
# Amour (2012)                7.9       76121      Drama    Romance      NaN
#
#                          MetaCritic      Budget  Runtime  CVotes10  CVotes09  \
# Title
# 12 Years a Slave (2013)        96.0  20000000.0  134 min     75556    126223
# 127 Hours (2010)               82.0  18000000.0   94 min     28939     44110
# 50/50 (2011)                   72.0   8000000.0  100 min     28304     47501
# About Time (2013)               NaN  12000000.0  123 min     38556     43170
# Amour (2012)                   94.0   8900000.0  127 min     11093     15944
#
# ...

# %%
movies3=pd.read_csv('IMDB.csv', usecols=['Title', 'Genre1', 'Runtime'])
movies3.head()
# Out:
#                      Title     Genre1  Runtime
# 0  12 Years a Slave (2013)  Biography  134 min
# 1         127 Hours (2010)  Adventure   94 min
# 2             50/50 (2011)     Comedy  100 min
# 3        About Time (2013)     Comedy  123 min
# 4             Amour (2012)      Drama  127 min

# %%
zillow=pd.read_csv('data-zillow.csv')
zillow.head()
# Out:
#         Date  RegionID    RegionName State                           Metro  \
# 0  5/31/2017      6181      New York    NY                        New York
# 1  5/31/2017     12447   Los Angeles    CA  Los Angeles-Long Beach-Anaheim
# 2  5/31/2017     17426       Chicago    IL                         Chicago
# 3  5/31/2017     13271  Philadelphia    PA                    Philadelphia
# 4  5/31/2017     40326       Phoenix    AZ                         Phoenix
#
#          County  SizeRank    Zhvi
# 0        Queens         0  672400
# 1   Los Angeles         1  629900
# 2          Cook         2  222700
# 3  Philadelphia         3  137300
# 4      Maricopa         4  211300

# %%
zillow.dtypes
# Out:
# Date          object
# RegionID       int64
# RegionName    object
# State         object
# Metro         object
# County        object
# SizeRank       int64
# Zhvi           int64
# dtype: object

# %%
zillow['Date']=pd.to_datetime(zillow['Date'])

# %%
zillow['Date'].dtypes
# Out:
# dtype('<M8[ns]')

# %%
zillow.dtypes
# Out:
# Date          datetime64[ns]
# RegionID               int64
# RegionName            object
# State                 object
# Metro                 object
# County                object
# SizeRank               int64
# Zhvi                   int64
# dtype: object

# %%
zillow['Date'].dt.year.value_counts()
# Out:
# 2017    10830
# Name: Date, dtype: int64

# %%
zillow['RegionName'] #I am selectingto view the contents of a single column

#Notes: A single column in pandas is called a series
# Out:
# 0                 New York
# 1              Los Angeles
# 2                  Chicago
# 3             Philadelphia
# 4                  Phoenix
#                ...
# 10825              Nehalem
# 10826    Clear Lake Shores
# 10827      Lebanon Borough
# 10828              Henrico
# 10829       East Hampstead
# Name: RegionName, Length: 10830, dtype: object

# %%
regions=zillow['RegionName']
regions.head()
# Out:
# 0        New York
# 1     Los Angeles
# 2         Chicago
# 3    Philadelphia
# 4         Phoenix
# Name: RegionName, dtype: object

# %%
regions[:25]
# Out:
# 0          New York
# 1       Los Angeles
# 2           Chicago
# 3      Philadelphia
# 4           Phoenix
# 5         Las Vegas
# 6         San Diego
# 7            Dallas
# 8          San Jose
# 9      Jacksonville
# 10    San Francisco
# 11           Austin
# 12          Detroit
# 13         Columbus
# 14          Memphis
# 15        Charlotte
# 16          El Paso
# 17           Boston
# 18          Seattle
# 19        Baltimore
# 20           Denver
# 21       Washington
# 22        Nashville
# 23        Milwaukee
# 24           Tucson
# Name: RegionName, dtype: object

# %%
type(regions)
# Out:
# pandas.core.series.Series

# %%
regions_multi=zillow[['RegionName', 'County']] #Whenever you select more than one column, use a doble square bracket
regions_multi.head()
# Out:
#      RegionName        County
# 0      New York        Queens
# 1   Los Angeles   Los Angeles
# 2       Chicago          Cook
# 3  Philadelphia  Philadelphia
# 4       Phoenix      Maricopa

# %%
zillow.head()
# Out:
#         Date  RegionID    RegionName State                           Metro  \
# 0 2017-05-31      6181      New York    NY                        New York
# 1 2017-05-31     12447   Los Angeles    CA  Los Angeles-Long Beach-Anaheim
# 2 2017-05-31     17426       Chicago    IL                         Chicago
# 3 2017-05-31     13271  Philadelphia    PA                    Philadelphia
# 4 2017-05-31     40326       Phoenix    AZ                         Phoenix
#
#          County  SizeRank    Zhvi
# 0        Queens         0  672400
# 1   Los Angeles         1  629900
# 2          Cook         2  222700
# 3  Philadelphia         3  137300
# 4      Maricopa         4  211300

# %%
type(regions_multi)
# Out:
# pandas.core.frame.DataFrame

# %%
zillow.shape
# Out:
# (10830, 8)

# %%
zillow['State'].value_counts()
# Out:
# PA    1208
# NY     717
# CA     701
# NJ     577
# FL     528
# OH     507
# IL     496
# MI     461
# IN     418
# TX     397
# TN     350
# MA     334
# MD     318
# NC     293
# WA     275
# WI     270
# GA     266
# VA     228
# MO     202
# NH     190
# CT     183
# CO     166
# OR     164
# MN     155
# AL     149
# LA     148
# SC     138
# MS     135
# KY     118
# AZ     102
# AR      82
# UT      81
# OK      70
# IA      63
# KS      52
# HI      43
# RI      41
# ID      33
# NV      26
# NM      26
# DE      26
# NE      20
# MT      20
# WV      17
# ND      12
# AK      12
# WY      10
# ME       1
# DC       1
# Name: State, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
top_10_states=zillow['State'].value_counts().head(n=10)
top_10_states
# Out:
# PA    1208
# NY     717
# CA     701
# NJ     577
# FL     528
# OH     507
# IL     496
# MI     461
# IN     418
# TX     397
# Name: State, dtype: int64

# %%
top_10_states.plot(kind='bar')

# %%
top_10_states.plot(kind='barh')
